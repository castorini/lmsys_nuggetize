# %%
import json

with open("/mnt/users/s8sharif/search_arena/005_gpt41/english_inversion_ids.json", "r", encoding="utf-8") as f:
    inversion_ids = json.load(f)

print(f"Total number of inversion ids: {len(inversion_ids)}")
# Out:
# Total number of inversion ids: 14

# %%
from pprint import pprint

for idx in inversion_ids:
    with open(f"/mnt/users/s8sharif/search_arena/005_gpt41/nuggets/requests_with_nuggets_{idx}.json", "r", encoding="utf-8") as f:
        data = json.load(f)
        pprint(data)
        break

for idx in inversion_ids:
    with open(f"/mnt/users/s8sharif/search_arena/005_gpt41/assignments/assigned_nuggets_{idx}.json", "r", encoding="utf-8") as f:
        data = json.load(f)
        pprint(data)
        break

# %%
from datasets import load_dataset

hf_dataset = load_dataset("lmarena-ai/search-arena-v1-7k", split="test")

data_all = {}
for row in hf_dataset:
    data_all[row["question_id"]] = row

# %%
import os, json

for query_id in data_all:
    if os.path.exists("/mnt/users/s8sharif/search_arena/gpt41_i_mode_5/nuggets/requests_with_nuggets_" + str(query_id) + ".json"):
        with open("/mnt/users/s8sharif/search_arena/gpt41_i_mode_5/nuggets/requests_with_nuggets_" + str(query_id) + ".json", "r", encoding="utf-8") as f:
            data = json.load(f)
            query_a = data_all[query_id]["messages_a"][0]['content'].strip()
            query_b = data_all[query_id]["messages_b"][0]['content'].strip()
            assert query_a == query_b
            print(query_a)
            print("###############")
# Out:
# Становлення держави Київська Русь. Видатні київські князі та їх реформи. Причини занепаду Давньоруської держави.
# ###############
# wiz
# ###############
# wiz
# ###############
# Napiš krátký příběh (max. 150 slov) na téma ‚Nečekaný vynález‘. Příběh by měl mít jasný začátek, prostředek a pointu. Hodnoťte originalitu, soudržnost a styl vyprávění.
# ###############
# what is SWE-Bench state of the art at the moment?
# ###############
# quels sont les identifiants nécessaires pour une migration OneDrive avec BitTitan, un email ou un UPN
# ###############
# Perbedaan inti antara syiah Zaidi, syiah dua belas imam, dan sunni.
# ###############
# donald trump news
# ###############
# What is the best CW code decoder based on AI model?
# ###############
# what are the news about harvard tuition fees
# ###############
# "The fallen angels you run with don't know that is us pain that makes us human after all" What anisong is this from?
# ###############
# ...

# %%
import json
import pandas as pd

all_data = []
with open("/mnt/users/n3thakur/2025/projects/nuggetization/search-arena-v1-7k/categorization/categories.gpt-4.1.prompt.researchy.questions.temp.0.7.jsonl", "r", encoding="utf-8") as f:
    for row in f:
        all_data.append(json.loads(row)["categories"])

df = pd.DataFrame(all_data)
df.head()
# Out:
#    ambiguous  incompleteness  assumptive  multi-faceted  knowledge-intensive  \
# 0          2               2           0              0                    4
# 1          1               1           1              1                    2
# 2          9              10           8              7                    7
# 3          9              10           8              7                    7
# 4          2               1           1              8                    8
#
#    subjective  reasoning-intensive  harmful
# 0           0                    0        0
# 1           0                    2        0
# 2           6                    6        0
# 3           6                    6        0
# 4           6                    7        0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Set the figure size
plt.rcParams["figure.figsize"] = (10,2)

# Define the columns to plot
columns = ['ambiguous', 'incompleteness', 'assumptive', 'multi-faceted', 'knowledge-intensive', 'subjective', 'reasoning-intensive', 'harmful']  # Replace with your column names

# Create a figure with multiple subplots
fig, axs = plt.subplots(1, len(columns), figsize=(20,2))

# Loop over the columns and create a histogram for each one
for i, col in enumerate(columns):
    data = df[col].to_list()
    sns.histplot(data, bins=10, kde=False, ax=axs[i])
    axs[i].set_title(col)
    axs[i].set_xlabel('')
    axs[i].set_ylabel('')

# Layout so plots do not overlap
fig.tight_layout()

# Show the plot
plt.show()

# %%
import json
import pandas as pd

inversion_ids = "/mnt/users/s8sharif/search_arena/gpt41_i_mode_5/english_inversion_ids.json"
with open(inversion_ids, "r", encoding="utf-8") as f:
    inversion_ids = json.load(f)

print(len(inversion_ids))

all_data = []
with open("/mnt/users/n3thakur/2025/projects/nuggetization/search-arena-v1-7k/categorization/categories.gpt-4.1.prompt.researchy.questions.temp.0.7.jsonl", "r", encoding="utf-8") as f:
    for row in f:
        data = json.loads(row)
        if data["question_id"] in inversion_ids:
            all_data.append(data["categories"])

print(len(all_data))
df = pd.DataFrame(all_data)
df.head()
# Out:
# 419
#    ambiguous  incompleteness  assumptive  multi-faceted  knowledge-intensive  \
# 0          2               3           1              2                    7
# 1          9              10           0              8                    1
# 2          2               3           2              3                    6
# 3          3               4           1              2                    3
# 4          2               6           1              1                    8
#
#    subjective  reasoning-intensive  harmful
# 0           1                    2        0
# 1           0                    0        0
# 2           6                    3        0
# 3           1                    1        0
# 4           1                    2        0
